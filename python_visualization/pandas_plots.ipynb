# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(20)
df = pd.DataFrame(np.random.rand(1000,1), 
                  index = pd.date_range('2021-07-18', periods = 1000),columns = ['data'])

# %%
df
# Out:
#                 data
# 2021-07-18  0.588131
# 2021-07-19  0.897714
# 2021-07-20  0.891531
# 2021-07-21  0.815837
# 2021-07-22  0.035890
# ...              ...
# 2024-04-08  0.992189
# 2024-04-09  0.756037
# 2024-04-10  0.299186
# 2024-04-11  0.261712
# 2024-04-12  0.968979
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.data.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
df.data.cumsum()
# Out:
# 2021-07-18      0.588131
# 2021-07-19      1.485845
# 2021-07-20      2.377375
# 2021-07-21      3.193213
# 2021-07-22      3.229102
#                  ...
# 2024-04-08    495.812936
# 2024-04-09    496.568973
# 2024-04-10    496.868159
# 2024-04-11    497.129872
# 2024-04-12    498.098851
# Freq: D, Name: data, Length: 1000, dtype: float64

# %%
df['data1'] = df.data.cumsum()

# %%
df['data2'] = df['data'].apply(lambda  x : x *3)

# %%
df
# Out:
#                 data       data1     data2
# 2021-07-18  0.588131    0.588131  1.764392
# 2021-07-19  0.897714    1.485845  2.693141
# 2021-07-20  0.891531    2.377375  2.674592
# 2021-07-21  0.815837    3.193213  2.447512
# 2021-07-22  0.035890    3.229102  0.107669
# ...              ...         ...       ...
# 2024-04-08  0.992189  495.812936  2.976566
# 2024-04-09  0.756037  496.568973  2.268112
# 2024-04-10  0.299186  496.868159  0.897559
# 2024-04-11  0.261712  497.129872  0.785137
# 2024-04-12  0.968979  498.098851  2.906937
#
# [1000 rows x 3 columns]

# %%
df.plot(figsize = (8,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## IRIS DATASET VISUALIZATION

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.plot(figsize = (8,5))
# Out:
# <AxesSubplot:>

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
pl = iris.plot(figsize = (8,5), 
          title = 'Iris data')
pl.set_xlabel('x axis ')
pl.set_ylabel('length')
# Out:
# Text(0, 0.5, 'length')

# %%
iris.iloc[0][0:4].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Titanic dataset visualization

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic['pclass'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
titanic['pclass'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.rand(10,4), columns = ['a','b','c','d'])

# %%
df3
# Out:
#           a         b         c         d
# 0  0.534850  0.141536  0.997549  0.663146
# 1  0.310007  0.127744  0.547494  0.029529
# 2  0.344711  0.929877  0.579118  0.643341
# 3  0.557322  0.307009  0.887460  0.760641
# 4  0.249756  0.648684  0.123295  0.508399
# 5  0.174770  0.759351  0.493705  0.254648
# 6  0.393292  0.008692  0.296240  0.232336
# 7  0.841515  0.442961  0.656447  0.080341
# 8  0.719348  0.575515  0.577130  0.251678
# 9  0.166954  0.675000  0.177515  0.724717

# %%
df3.plot.bar()  # plotting all the records ( indx and values )
# Out:
# <AxesSubplot:>

# %%
df3.plot.barh()
# Out:
# <AxesSubplot:>

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris['sepal_width'].plot.hist(color = 'greY')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = 'True', bins = 100, figsize = (9,6),
         title = "histogram of iris", orientation = 'horizontal')
# Out:
# <AxesSubplot:title={'center':'histogram of iris'}, xlabel='Frequency'>

# %%
iris.hist(figsize = (10,6), color = 'red', alpha = 0.8)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
iris.plot.scatter(x = 'sepal_length', y  = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.plot.scatter(x = 'sepal_length', y  = 'sepal_width', c = 'petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.plot.scatter(x = 'sepal_length', y = 'sepal_width', 
                  label = 'data', 
                  s = 90, 
                  c = 'petal_width', figsize = (9,6))
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.plot.hexbin(x = 'sepal_length', y = 'sepal_width',label = 'data', gridsize = 10, 
                figsize = (9,6))
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df
# Out:
#                 data       data1     data2
# 2021-07-18  0.588131    0.588131  1.764392
# 2021-07-19  0.897714    1.485845  2.693141
# 2021-07-20  0.891531    2.377375  2.674592
# 2021-07-21  0.815837    3.193213  2.447512
# 2021-07-22  0.035890    3.229102  0.107669
# ...              ...         ...       ...
# 2024-04-08  0.992189  495.812936  2.976566
# 2024-04-09  0.756037  496.568973  2.268112
# 2024-04-10  0.299186  496.868159  0.897559
# 2024-04-11  0.261712  497.129872  0.785137
# 2024-04-12  0.968979  498.098851  2.906937
#
# [1000 rows x 3 columns]

# %%
d = df.iloc[0]
d
# Out:
# data     0.588131
# data1    0.588131
# data2    1.764392
# Name: 2021-07-18 00:00:00, dtype: float64

# %%
d.plot.pie()
# Out:
# <AxesSubplot:ylabel='2021-07-18 00:00:00'>

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_sub1 = iris.head(3).T
iris_sub1
# Out:
#                    0       1       2
# sepal_length     5.1     4.9     4.7
# sepal_width      3.5     3.0     3.2
# petal_length     1.4     1.4     1.3
# petal_width      0.2     0.2     0.2
# species       setosa  setosa  setosa

# %%
iris_sub1[0:4].plot.pie(subplots = True, figsize = (20,20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
iris_sub1[0:4].plot.pie(subplots = True, figsize = (20,20),autopct = '%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
pd.plotting.scatter_matrix(iris, figsize = (10,8), diagonal = 'hist')
plt.show()

# %%
pd.plotting.scatter_matrix(iris, figsize = (10,8), diagonal = 'kde')
plt.show()

# %%
df['data'].plot(style = 'y.', legend = True, label = 'data')
# Out:
# <AxesSubplot:>
